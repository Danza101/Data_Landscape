# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Initial_Breakdown_Plan.xlsx - Dataset.csv')

# %%
data2 = {3000 , 2000 , 700 , 450 , 500 , 400 , 1100 , 8900 , 1300 , 300}

# %%
data1 = df.groupby('Location').count()['RecordID']

# %%
data1.sor
# Out:
# Location
# Belfast        8136
# Birmingham     7396
# Bristol        1722
# Cardiff         144
# Edinburgh      1632
# Glasgow        1270
# Leeds          2842
# London        55293
# Manchester     5309
# Reading        1141
# Watford        1618
# Name: RecordID, dtype: int64

# %%
# Manually inputted data from the image
data = {
    'Belfast': 8136,
    'Birmingham': 7396,
    'Bristol': 1722,
    'Cardiff': 144,
    'Edinburgh': 1632,
    'Glasgow': 1270,
    'Leeds': 2842,
    'London': 55293,
    'Manchester': 5309,
    'Reading': 1141,
    'Watford': 1618
}

# Create the Series
s = pd.Series(data)

# Convert the Series to a NumPy array
numbers_array = s.values  # or s.to_numpy()

print(numbers_array)
# Out:
# [ 8136  7396  1722   144  1632  1270  2842 55293  5309  1141  1618]

# %%
# Assuming 'data2' is now a list and in the correct order
data2_list = [3000, 2000, 700, 450, 500, 400, 1100, 8900, 1300, 300]

# Your list of numbers is provided as a list in the same order
data1_list = [8136, 7396, 1722, 144, 1632, 1270, 2842, 55293, 5309, 1618]

# Making sure both lists have the same length
if len(data2_list) == len(data1_list):
    # Use list comprehension to divide elements from the first list by the second list
    division_result = [n1 / n2 for n1, n2 in zip(data1_list, data2_list)]
else:
    print("The lists are not of the same length.")

print(division_result)
# Out:
# [2.712, 3.698, 2.46, 0.32, 3.264, 3.175, 2.5836363636363635, 6.212696629213483, 4.083846153846154, 5.3933333333333335]

# %%
# Data to plot
labels = 'Belfast', 'Birmingham', 'Bristol', 'Cardiff' , 'Edinburugh' , 'Glasgow' , 'Leeds' , 'London' , 'Manchester' , 'Watford'
sizes = [2.7, 3.7, 2.5, 0.3, 3.3 , 3.2 , 2.6 , 6.2 , 4.1 , 5.4]

# Plotting the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)

# Adding the legend
plt.legend(labels, title="Programming Languages", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Belfast', 'Birmingham', 'Bristol', 'Cardiff', 'Edinburgh', 'Glasgow', 'Leeds', 'London', 'Manchester', 'Watford']
sizes = [2.7, 3.7, 2.5, 0.3, 3.3, 3.2, 2.6, 6.2, 4.1, 5.4]

# Plotting the pie chart
plt.pie(sizes, labels=labels, shadow=True, startangle=140)

# Creating custom labels for the legend
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(v=val)
    return my_autopct

custom_labels = ['{0} - {1}'.format(i, j) for i, j in zip(labels, make_autopct(sizes)(sizes))]

# Adding the legend with custom labels
plt.legend(custom_labels, title="Cities", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Display the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      15         return '{v:d}'.format(v=val)
#      16     return my_autopct
# ---> 18 custom_labels = ['{0} - {1}'.format(i, j) for i, j in zip(labels, make_autopct(sizes)(sizes))]
#      20 # Adding the legend with custom labels
#      21 plt.legend(custom_labels, title="Cities", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
#
# Cell In[5], line 14, in make_autopct.<locals>.my_autopct(pct)
#      12 def my_autopct(pct):
#      13     total = sum(values)
# ---> 14     val = int(round(pct*total/100.0))
#      15     return '{v:d}'.format(v=val)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Belfast', 'Birmingham', 'Bristol', 'Cardiff', 'Edinburgh', 'Glasgow', 'Leeds', 'London', 'Manchester', 'Watford']
sizes = [2.7, 3.7, 2.5, 0.3, 3.3, 3.2, 2.6, 6.2, 4.1, 5.4]

# Plotting the pie chart
plt.bar(sizes, startangle=140)

plt.title('Purchases to employee ratio')

# Creating custom labels for the legend by including the city names and the corresponding sizes
custom_labels = ['{0} - {1:.1f}'.format(label, size) for label, size in zip(labels, sizes)]

# Adding the legend with custom labels
plt.legend(custom_labels, title="Cities", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Equal aspect ratio ensures that pie is drawn as a circle.
plt.axis('equal')

# Display the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 sizes = [2.7, 3.7, 2.5, 0.3, 3.3, 3.2, 2.6, 6.2, 4.1, 5.4]
#       7 # Plotting the pie chart
# ----> 8 plt.bar(sizes, startangle=140)
#      10 plt.title('Purchases to employee ratio')
#      12 # Creating custom labels for the legend by including the city names and the corresponding sizes
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.figure(figsize=(16, 7))
plt.bar(labels , sizes)
plt.title('Purchases to employee ratio')
plt.show()
